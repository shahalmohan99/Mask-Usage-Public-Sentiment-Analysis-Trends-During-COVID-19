# %% [markdown]
# # Mask Usage & Public Sentiment Analysis
# This Jupyter Notebook contains data analysis and visualization related to **mask usage trends and public sentiment** during COVID-19.
#
# We will:
# - Install necessary libraries
# - Load and clean data
# - Perform sentiment analysis
# - Visualize trends

# %% [markdown]
# ##  Installing Required Libraries
# We need to install the required Python libraries for data analysis, machine learning, and Twitter scraping.

# %%
# !pip install pandas 
# !pip install numpy
# !pip install matplotlib
# !pip install scikit-learn
# !pip install tweepy
# Out:
# Requirement already satisfied: pandas in c:\users\almoh\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\almoh\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\almoh\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\almoh\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\almoh\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\almoh\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: numpy in c:\users\almoh\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\almoh\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\almoh\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\almoh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\almoh\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\almoh\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\almoh\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\almoh\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\almoh\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tweepy in c:\users\almoh\anaconda3\lib\site-packages (4.14.0)
# Requirement already satisfied: oauthlib<4,>=3.2.0 in c:\users\almoh\anaconda3\lib\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied: requests<3,>=2.27.0 in c:\users\almoh\anaconda3\lib\site-packages (from tweepy) (2.32.3)
# Requirement already satisfied: requests-oauthlib<2,>=1.2.0 in c:\users\almoh\anaconda3\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\almoh\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\almoh\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\almoh\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\almoh\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2024.8.30)

# %% [markdown]
# ##  Fixing `snscrape` Issues
# Since `snscrape` is used for scraping Twitter without API authentication, we need to uninstall any corrupted versions and reinstall it.

# %%
# !pip uninstall snscrape -y
# !pip install snscrape
# Out:
# Found existing installation: snscrape 0.7.0.20230622
# Uninstalling snscrape-0.7.0.20230622:
#   Successfully uninstalled snscrape-0.7.0.20230622
# Collecting snscrape
#   Using cached snscrape-0.7.0.20230622-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: requests[socks] in c:\users\almoh\anaconda3\lib\site-packages (from snscrape) (2.32.3)
# Requirement already satisfied: lxml in c:\users\almoh\anaconda3\lib\site-packages (from snscrape) (5.2.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\almoh\anaconda3\lib\site-packages (from snscrape) (4.12.3)
# Requirement already satisfied: filelock in c:\users\almoh\anaconda3\lib\site-packages (from snscrape) (3.13.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\almoh\anaconda3\lib\site-packages (from beautifulsoup4->snscrape) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\almoh\anaconda3\lib\site-packages (from requests[socks]->snscrape) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\almoh\anaconda3\lib\site-packages (from requests[socks]->snscrape) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\almoh\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\almoh\anaconda3\lib\site-packages (from requests[socks]->snscrape) (2024.8.30)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\almoh\anaconda3\lib\site-packages (from requests[socks]->snscrape) (1.7.1)
# Using cached snscrape-0.7.0.20230622-py3-none-any.whl (74 kB)
# Installing collected packages: snscrape
# Successfully installed snscrape-0.7.0.20230622

# %% [markdown]
# ##  Importing Required Libraries
# Once the libraries are installed, we import them for use in the notebook.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tweepy
from wordcloud import WordCloud

# %% [markdown]
# ##  Loading the Dataset
# We load the CSV file that contains public sentiment data about mask usage during COVID-19.

# %%
df = pd.read_csv('mask_usage_reactions.csv')
df.head()
# Out:
#    Year                                            Comment Sentiment  \
# 0  2019  Masks are mostly used in hospitals, not daily ...   Neutral
# 1  2019        Only a few people wear masks for pollution.   Neutral
# 2  2019                   Wearing masks daily is uncommon.   Neutral
# 3  2019     I see some people wearing masks, but not many.   Neutral
# 4  2019          Most people don't wear masks unless sick.   Neutral
#
#    Usage_Rate_Percentage
# 0                      5
# 1                      5
# 2                      5
# 3                      7
# 4                      8

# %% [markdown]
# ##  Data Cleaning
# Let's check for missing values and clean the dataset if needed.

# %%
df.isnull().sum()
# Out:
# Year                     0
# Comment                  0
# Sentiment                0
# Usage_Rate_Percentage    0
# dtype: int64

# %% [markdown]
# ##  Mask Usage Trend Over the Years
# We visualize the trend of mask usage percentages over the years (2019-2022).

# %%
plt.figure(figsize=(8, 5))
sns.lineplot(x=df['Year'], y=df['Usage_Rate_Percentage'], marker='o', linestyle='-', color='b')
plt.title('Mask Usage Rate Over the Years (2019-2022)')
plt.xlabel('Year')
plt.ylabel('Usage Rate (%)')
plt.grid(True)
plt.show()

# %% [markdown]
# ##  Mask Usage by Country
# We analyze the mask usage in public places across different countries.

# %%
import pandas as pd

file_path = '/Users/almoh/Downloads/covid&Twitter.csv'
timeline = pd.read_csv(file_path)
print(timeline.head())
print(timeline.columns)
# Out:
#                                                                            Category: All categories
# Country        using mask: (4/1/19 - 1/18/25) COVID-19: (4/1/19 - 1/18/25)    X: (4/1/19 - 1/18/25)
# Bhutan         NaN                            NaN                                               NaN
# American Samoa NaN                            NaN                                               NaN
# Brunei         <1%                            45%                                               55%
# Philippines    <1%                            49%                                               51%
# Index(['Category: All categories'], dtype='object')

# %%
df_csv_fixed = pd.read_csv(file_path, skiprows=1)
df_csv_fixed.columns = ["Country", "Mask Usage (%)", "COVID-19 Impact (%)", "Other"]
df_filtered = df_csv_fixed[["Country", "Mask Usage (%)"]].dropna()
df_filtered["Mask Usage (%)"] = df_filtered["Mask Usage (%)"].replace("<1%", "0.5").str.replace("%", "").astype(float)
df_filtered = df_filtered.sort_values(by="Mask Usage (%)", ascending=False).head(15)  # Top 15 countries

plt.figure(figsize=(12, 6))
sns.barplot(x="Mask Usage (%)", y="Country", data=df_filtered, palette="Blues_r")
plt.title("Mask Usage in Public Places by Country (COVID-19)")
plt.xlabel("Mask Usage Percentage (%)")
plt.ylabel("Country")
plt.grid(axis="x", linestyle="--", alpha=0.6)
plt.show()
# Out:
# C:\Users\almoh\AppData\Local\Temp\ipykernel_15676\3939035866.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Mask Usage (%)", y="Country", data=df_filtered, palette="Blues_r")

# %% [markdown]
# ##  Sentiment Analysis of Public Reactions
# We visualize the public sentiment regarding mask usage over the years.

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df, x='Year', hue='Sentiment', palette='viridis')
plt.title('Sentiment Distribution About Mask Usage (2019-2022)')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend(title='Sentiment')
plt.show()

# %%
text = " ".join(comment for comment in df.Comment)
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.title("Word Cloud of Public Reactions to Mask Usage")
plt.show()
